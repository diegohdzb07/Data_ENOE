# %%
import pandas as pd 
from sklearn import tree
import matplotlib
import matplotlib.pyplot as plt
import openpyxl
datos = pd.read_csv("../databases/full_database.csv")

# %%
datos.head()
# Out:
#    cs_p13_1  eda7c  sex  e_con  rama  ambito2  emp_ppal  pos_ocu  ing_x_hrs  \
# 0         1      3    1      1     3        4         2        1   52.09302
# 1         1      2    1      3     3        2         2        1   65.11628
# 2         1      2    1      3     3        2         2        1   73.64341
# 3         2      5    1      1     3        1         1        3   66.66667
# 4         2      4    2      3     2        2         1        1   37.50000
#
#    hrsocup  ent   ano  trim
# 0       25    9  2020     3
# 1       25    9  2020     3
# 2       24    9  2020     3
# 3        9    9  2020     3
# 4       24    9  2020     3

# %%
datos.describe()
# Out:
#            cs_p13_1         eda7c           sex         e_con          rama  \
# count  1.502149e+06  1.502149e+06  1.502149e+06  1.502149e+06  1.502149e+06
# mean   1.741002e+00  3.320203e+00  1.400798e+00  1.665227e+00  2.728614e+00
# std    8.422604e-01  1.315314e+00  4.900603e-01  8.845338e-01  4.446748e-01
# min    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  2.000000e+00
# 25%    1.000000e+00  2.000000e+00  1.000000e+00  1.000000e+00  2.000000e+00
# 50%    2.000000e+00  3.000000e+00  1.000000e+00  1.000000e+00  3.000000e+00
# 75%    2.000000e+00  4.000000e+00  2.000000e+00  3.000000e+00  3.000000e+00
# max    4.000000e+00  6.000000e+00  2.000000e+00  3.000000e+00  3.000000e+00
#
#             ambito2      emp_ppal       pos_ocu     ing_x_hrs       hrsocup  \
# count  1.502149e+06  1.502149e+06  1.502149e+06  1.502149e+06  1.502149e+06
# mean   2.346756e+00  1.544698e+00  1.407535e+00  4.356658e+01  4.404573e+01
# ...

# %%
#Filtrar por ent
datos = datos[datos['ent'] == 9]

# %%
datos = datos[["cs_p13_1", "ano"]]

# %%
datos_agrupados = datos.groupby(["ano", "cs_p13_1"]).value_counts()
datos_agrupados = datos_agrupados.to_frame(name = "total").reset_index()#.drop("total", axis = 1)
datos_agrupados = datos_agrupados.pivot(index = "ano",columns= "cs_p13_1",values= "total").fillna(0)

# %%
datos_agrupados.apply(lambda x: 100 * x/x.sum(), axis = 1)
# Out:
# cs_p13_1          1          2          3         4
# ano
# 2005      49.902549  28.260870  19.805097  2.031484
# 2006      48.439507  28.534724  20.584901  2.440868
# 2007      47.589279  29.389701  20.997109  2.023912
# 2008      47.790032  29.446886  20.548968  2.214114
# 2009      47.750865  29.803315  20.023675  2.422145
# 2010      48.131309  30.226425  19.296172  2.346094
# 2011      48.530549  30.191415  19.209203  2.068832
# 2012      46.943528  31.602950  19.280031  2.173491
# 2013      47.605255  30.195510  19.871729  2.327506
# 2014      50.256235  29.689101  18.084501  1.970163
# 2015      49.415653  29.087475  19.135875  2.360996
# 2016      46.325033  30.879346  20.365692  2.429929
# 2017      44.792695  32.132280  20.841560  2.233465
# 2018      47.362266  31.237006  19.425676  1.975052
# 2019      46.333460  32.109050  19.626404  1.931087
# 2020      43.408252  32.053002  21.502851  3.035894
# 2021      40.523727  33.752894  22.656250  3.067130
# ...
