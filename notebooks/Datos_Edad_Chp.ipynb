# %%
import pandas as pd 
from sklearn import tree
import matplotlib
import matplotlib.pyplot as plt
import openpyxl
datos = pd.read_csv("../databases/full_database.csv")

# %%
datos.head()
# Out:
#    cs_p13_1  eda7c  sex  e_con  rama  ambito2  emp_ppal  pos_ocu  ing_x_hrs  \
# 0         1      3    1      1     3        4         2        1   52.09302
# 1         1      2    1      3     3        2         2        1   65.11628
# 2         1      2    1      3     3        2         2        1   73.64341
# 3         2      5    1      1     3        1         1        3   66.66667
# 4         2      4    2      3     2        2         1        1   37.50000
#
#    hrsocup  ent   ano  trim
# 0       25    9  2020     3
# 1       25    9  2020     3
# 2       24    9  2020     3
# 3        9    9  2020     3
# 4       24    9  2020     3

# %%
#Filtrar por ent
datos = datos[datos['ent'] == 7]

# %%
datos = datos[["eda7c", "ano"]]

# %%
datos_agrupados = datos.groupby(["ano", "eda7c"]).value_counts()
datos_agrupados = datos_agrupados.to_frame(name = "total").reset_index()#.drop("total", axis = 1)
datos_agrupados = datos_agrupados.pivot(index = "ano",columns= "eda7c",values= "total").fillna(0)

# %%
datos_agrupados.apply(lambda x: 100 * x/x.sum(), axis = 1)
# Out:
# eda7c         1          2          3          4          5         6
# ano
# 2005   7.083168  29.931025  28.995888  20.486802   9.968166  3.534952
# 2006   7.145227  29.350494  28.640616  20.513501  10.289922  4.060240
# 2007   7.173554  28.178512  28.112397  21.666116  10.300826  4.568595
# 2008   6.727603  28.227703  27.306943  22.830835  10.303112  4.603804
# 2009   6.826472  27.651120  27.657634  22.466128  10.995310  4.403335
# 2010   6.534776  28.377125  26.392581  22.819165  11.233385  4.642968
# 2011   6.148063  27.643986  26.898573  22.833843  11.697248  4.778287
# 2012   5.631937  27.358729  27.377649  22.723259  11.957619  4.950807
# 2013   5.553050  26.670102  27.133930  22.431231  13.019391  5.192295
# 2014   5.038785  25.428590  27.638355  23.473046  12.945701  5.475523
# 2015   5.194723  26.093543  27.198132  23.007006  12.901597  5.604999
# 2016   4.876463  26.319896  26.378414  23.634590  13.348505  5.442133
# ...
